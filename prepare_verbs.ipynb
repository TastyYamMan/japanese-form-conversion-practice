# %%
import yaml
from itertools import chain
import json
import pandas as pd

# %%
with open("minna-no-ds.yaml", "r", encoding="utf-8") as f:
    ds = yaml.load(f, Loader=yaml.FullLoader)

# %%
lessons = [ds[f'lesson-{str(i+1).zfill(2)}'] for i in range(24)]

# %%
GROUP_EXCEPTIONS = {
    '1': ['伸ばします'],
    '2': ['起きます', 'できます']
}

def group(verb):
    for group_num, exception_verbs in GROUP_EXCEPTIONS.items():
        if verb['kanji'] in exception_verbs:
            return int(group_num)
    if (verb['kanji'][-3:] == 'します' and len(verb['kanji']) > 4) or verb['kanji'][-3:] == '来ます':
        return 3
    elif verb['romaji'][-5] == 'e' or len(verb['kana']) == 3 or len(verb['kanji']) == 3:
        return 2
    elif verb['romaji'][-5] == 'i':
        return 1

# %%
VERB_EXCEPTIONS = ['役に 立ちます']
def get_verbs(lesson):
    verbs = []
    for word in lesson:
        if 2 not in word['edition']:
            continue
        if 'を' in word['kana']:
            continue
        if word['kanji'] in VERB_EXCEPTIONS:
            continue
        if word['kanji'] is None:
            word['kanji'] = word['kana']
        if word['kanji'] == '行ます':
            word['kanji'] = '行きます'
        if word['kanji'] == '住ます':
            word['kanji'] = '住みます'
        if word['kana'][-2:] == 'ます':
            cleaned = {'kanji': word['kanji'], 'kana' : word['kana'], 'romaji' : word['romaji'], 'group': group(word)}
            verbs.append(cleaned)
    return verbs

# %%
verbs = list(chain.from_iterable([get_verbs(lesson) for lesson in lessons]))
verbs
# Out:
# [{'kanji': '起きます', 'kana': 'おきます', 'romaji': 'okimasu', 'group': 2},
#  {'kanji': '寝ます', 'kana': 'ねます', 'romaji': 'nemasu', 'group': 2},
#  {'kanji': '働きます', 'kana': 'はたらきます', 'romaji': 'hatarakimasu', 'group': 1},
#  {'kanji': '休みます', 'kana': 'やすみます', 'romaji': 'yasumimasu', 'group': 1},
#  {'kanji': '勉強します', 'kana': 'べんきょうします', 'romaji': 'benkyōshimasu', 'group': 3},
#  {'kanji': '終わります', 'kana': 'おわります', 'romaji': 'owarimasu', 'group': 1},
#  {'kanji': '行きます', 'kana': 'いきます', 'romaji': 'ikimasu', 'group': 1},
#  {'kanji': '来ます', 'kana': 'きます', 'romaji': 'kimasu', 'group': 3},
#  {'kanji': '帰ります', 'kana': 'かえります', 'romaji': 'kaerimasu', 'group': 1},
#  {'kanji': '食べます', 'kana': 'たべます', 'romaji': 'tabemasu', 'group': 2},
#  {'kanji': '飲みます', 'kana': 'のみます', 'romaji': 'nomimasu', 'group': 1},
#  {'kanji': '見ます', 'kana': 'みます', 'romaji': 'mimasu', 'group': 2},
#  {'kanji': '聞きます', 'kana': 'ききます', 'romaji': 'kikimasu', 'group': 1},
#  {'kanji': '読みます', 'kana': 'よみます', 'romaji': 'yomimasu', 'group': 1},
#  {'kanji': '書きます', 'kana': 'かきます', 'romaji': 'kakimasu', 'group': 1},
#  {'kanji': '買います', 'kana': 'かいます', 'romaji': 'kaimasu', 'group': 1},
#  {'kanji': 'します', 'kana': 'します', 'romaji': 'shimasu', 'group': 2},
#  {'kanji': '切ります', 'kana': 'きります', 'romaji': 'kirimasu', 'group': 1},
#  {'kanji': '送ります', 'kana': 'おくります', 'romaji': 'okurimasu', 'group': 1},
#  {'kanji': 'あげます', 'kana': 'あげます', 'romaji': 'agemasu', 'group': 2},
#  {'kanji': 'もらいます', 'kana': 'もらいます', 'romaji': 'moraimasu', 'group': 1},
#  {'kanji': '貨します', 'kana': 'かします', 'romaji': 'kashimasu', 'group': 1},
#  {'kanji': '借ります', 'kana': 'かります', 'romaji': 'karimasu', 'group': 1},
#  {'kanji': '教えます', 'kana': 'おしえます', 'romaji': 'oshiemasu', 'group': 2},
#  {'kanji': '習います', 'kana': 'ならいます', 'romaji': 'naraimasu', 'group': 1},
#  {'kanji': 'わかります', 'kana': 'わかります', 'romaji': 'wakarimasu', 'group': 1},
#  {'kanji': 'あります', 'kana': 'あります', 'romaji': 'arimasu', 'group': 1},
#  {'kanji': 'あります', 'kana': 'あります', 'romaji': 'arimasu', 'group': 1},
#  {'kanji': 'います', 'kana': 'います', 'romaji': 'imasu', 'group': 2},
#  {'kanji': 'かかります', 'kana': 'かかります', 'romaji': 'kakarimasu', 'group': 1},
#  {'kanji': '遊びます', 'kana': 'あそびます', 'romaji': 'asobimasu', 'group': 1},
#  {'kanji': '泳ぎます', 'kana': 'およぎます', 'romaji': 'oyogimasu', 'group': 1},
#  {'kanji': '迎えます', 'kana': 'むかえます', 'romaji': 'mukaemasu', 'group': 2},
#  {'kanji': '疲れます', 'kana': 'つかれます', 'romaji': 'tsukaremasu', 'group': 2},
#  {'kanji': '結婚します', 'kana': 'けっこんします', 'romaji': 'kekkonshimasu', 'group': 3},
#  {'kanji': '買い物します',
#   'kana': 'かいものします',
#   'romaji': 'kaimonoshimasu',
#   'group': 3},
#  {'kanji': '食事します', 'kana': 'しょくじします', 'romaji': 'shokujishimasu', 'group': 3},
#  {'kanji': 'のどが かわきます',
#   'kana': 'のどが かわきます',
#   'romaji': 'nodoga kawakimasu',
#   'group': 1},
#  {'kanji': 'おなかが すきます',
#   'kana': 'おなかが すきます',
#   'romaji': 'onakaga sukimasu',
#   'group': 1},
#  {'kanji': 'つけます', 'kana': 'つけます', 'romaji': 'tsukemasu', 'group': 2},
#  {'kanji': '消します', 'kana': 'けします', 'romaji': 'keshimasu', 'group': 1},
#  {'kanji': '開けます', 'kana': 'あけます', 'romaji': 'akemasu', 'group': 2},
#  {'kanji': '閉めます', 'kana': 'しめます', 'romaji': 'shimemasu', 'group': 2},
#  {'kanji': '急ぎます', 'kana': 'いそぎます', 'romaji': 'isogimasu', 'group': 1},
#  {'kanji': '待ちます', 'kana': 'まちます', 'romaji': 'machimasu', 'group': 1},
#  {'kanji': '持ちます', 'kana': 'もちます', 'romaji': 'mochimasu', 'group': 1},
#  {'kanji': '取ります', 'kana': 'とります', 'romaji': 'torimasu', 'group': 1},
#  {'kanji': '手伝います', 'kana': 'てつだいます', 'romaji': 'tetsudaimasu', 'group': 1},
#  {'kanji': '呼びます', 'kana': 'よびます', 'romaji': 'yobimasu', 'group': 1},
#  {'kanji': '話します', 'kana': 'はなします', 'romaji': 'hanashimasu', 'group': 1},
#  {'kanji': '使います', 'kana': 'つかいます', 'romaji': 'tsukaimasu', 'group': 1},
#  {'kanji': '止めます', 'kana': 'とめます', 'romaji': 'tomemasu', 'group': 2},
#  {'kanji': '見せます', 'kana': 'みせます', 'romaji': 'misemasu', 'group': 2},
#  {'kanji': '座ります', 'kana': 'すわります', 'romaji': 'suwarimasu', 'group': 1},
#  {'kanji': '立ちます', 'kana': 'たちます', 'romaji': 'tachimasu', 'group': 1},
#  {'kanji': 'コピーします', 'kana': 'コピーします', 'romaji': 'kopiishimasu', 'group': 3},
#  {'kanji': '置きます', 'kana': 'おきます', 'romaji': 'okimasu', 'group': 1},
#  {'kanji': '作ります、造ります', 'kana': 'つくります', 'romaji': 'tsukurimasu', 'group': 1},
#  {'kanji': '売ります', 'kana': 'うります', 'romaji': 'urimasu', 'group': 1},
#  {'kanji': '知ります', 'kana': 'しります', 'romaji': 'shirimasu', 'group': 1},
#  {'kanji': '住みます', 'kana': 'すみます', 'romaji': 'sumimasu', 'group': 1},
#  {'kanji': '研究します', 'kana': 'けんきゅうします', 'romaji': 'kenkyūshimasu', 'group': 3},
#  {'kanji': '思い出します', 'kana': 'おもいだします', 'romaji': 'omoidashimasu', 'group': 3},
#  {'kanji': 'いらっしゃいます',
#   'kana': 'いらっしゃいます',
#   'romaji': 'irasshaimasu',
#   'group': 1},
#  {'kanji': '乗り換えます', 'kana': 'のりかえます', 'romaji': 'norikaemasu', 'group': 2},
#  {'kanji': '入れます', 'kana': 'いれます', 'romaji': 'iremasu', 'group': 2},
#  {'kanji': '出します', 'kana': 'だします', 'romaji': 'dashimasu', 'group': 1},
#  {'kanji': '押します', 'kana': 'おします', 'romaji': 'oshimasu', 'group': 1},
#  {'kanji': '飲みます', 'kana': 'のみます', 'romaji': 'nomimasu', 'group': 1},
#  {'kanji': '始めます', 'kana': 'はじめます', 'romaji': 'hajimemasu', 'group': 2},
#  {'kanji': '見学します', 'kana': 'けんがくします', 'romaji': 'kengakushimasu', 'group': 3},
#  {'kanji': '電話します', 'kana': 'でんわします', 'romaji': 'denwashimasu', 'group': 3},
#  {'kanji': '覚えます', 'kana': 'おぼえます', 'romaji': 'oboemasu', 'group': 2},
#  {'kanji': '忘れます', 'kana': 'わすれます', 'romaji': 'wasuremasu', 'group': 2},
#  {'kanji': 'なくします', 'kana': 'なくします', 'romaji': 'nakushimasu', 'group': 3},
#  {'kanji': '払います', 'kana': 'はらいます', 'romaji': 'haraimasu', 'group': 1},
#  {'kanji': '返します', 'kana': 'かえします', 'romaji': 'kaeshimasu', 'group': 1},
#  {'kanji': '出かけます', 'kana': 'でかけます', 'romaji': 'dekakemasu', 'group': 2},
#  {'kanji': '脱ぎます', 'kana': 'ぬぎます', 'romaji': 'nugimasu', 'group': 1},
#  {'kanji': '持って 行きます',
#   'kana': 'もって いきます',
#   'romaji': 'motte ikimasu',
#   'group': 1},
#  {'kanji': '持って 来ます', 'kana': 'もって きます', 'romaji': 'motte kimasu', 'group': 3},
#  {'kanji': '心配します', 'kana': 'しんぱいします', 'romaji': 'shinpaishimasu', 'group': 3},
#  {'kanji': '残業します', 'kana': 'ざんぎょうします', 'romaji': 'zangyōshimasu', 'group': 3},
#  {'kanji': '出張します',
#   'kana': 'しゅっちょうします',
#   'romaji': 'shutchōshimasu',
#   'group': 3},
#  {'kanji': 'できます', 'kana': 'できます', 'romaji': 'dekimasu', 'group': 2},
#  {'kanji': '洗います', 'kana': 'あらいます', 'romaji': 'araimasu', 'group': 1},
#  {'kanji': '弾きます', 'kana': 'ひきます', 'romaji': 'hikimasu', 'group': 1},
#  {'kanji': '歌います', 'kana': 'うたいます', 'romaji': 'utaimasu', 'group': 1},
#  {'kanji': '集めます', 'kana': 'あつめます', 'romaji': 'atsumemasu', 'group': 2},
#  {'kanji': '捨てます', 'kana': 'すてます', 'romaji': 'sutemasu', 'group': 2},
#  {'kanji': '換えます', 'kana': 'かえます', 'romaji': 'kaemasu', 'group': 2},
#  {'kanji': '運転します', 'kana': 'うんてんします', 'romaji': 'untenshimasu', 'group': 3},
#  {'kanji': '予約します', 'kana': 'よやくします', 'romaji': 'yoyakushimasu', 'group': 3},
#  {'kanji': '登ります、上ります', 'kana': 'のぼります', 'romaji': 'noborimasu', 'group': 1},
#  {'kanji': '掃除します', 'kana': 'そうじします', 'romaji': 'sōjishimasu', 'group': 3},
#  {'kanji': '洗濯します', 'kana': 'せんたくします', 'romaji': 'sentakushimasu', 'group': 3},
#  {'kanji': 'なります', 'kana': 'なります', 'romaji': 'narimasu', 'group': 1},
#  {'kanji': '調べます', 'kana': 'しらべます', 'romaji': 'shirabemasu', 'group': 2},
#  {'kanji': '修理します', 'kana': 'しゅうりします', 'romaji': 'shūrishimasu', 'group': 3},
#  {'kanji': '思います', 'kana': 'おもいます', 'romaji': 'omoimasu', 'group': 1},
#  {'kanji': '言います', 'kana': 'いいます', 'romaji': 'iimasu', 'group': 1},
#  {'kanji': '勝ちます', 'kana': 'かちます', 'romaji': 'kachimasu', 'group': 1},
#  {'kanji': '負けます', 'kana': 'まけます', 'romaji': 'makemasu', 'group': 2},
#  {'kanji': '動きます', 'kana': 'うごきます', 'romaji': 'ugokimasu', 'group': 1},
#  {'kanji': '留学します',
#   'kana': 'りゅうがくします',
#   'romaji': 'ryūgakushimasu',
#   'group': 3},
#  {'kanji': '着ます', 'kana': 'きます', 'romaji': 'kimasu', 'group': 2},
#  {'kanji': 'はきます', 'kana': 'はきます', 'romaji': 'hakimasu', 'group': 1},
#  {'kanji': 'かぶります', 'kana': 'かぶります', 'romaji': 'kaburimasu', 'group': 1},
#  {'kanji': '生まれます', 'kana': 'うまれます', 'romaji': 'umaremasu', 'group': 2},
#  {'kanji': '回します', 'kana': 'まわします', 'romaji': 'mawashimasu', 'group': 1},
#  {'kanji': '引きます', 'kana': 'ひきます', 'romaji': 'hikimasu', 'group': 1},
#  {'kanji': '変えます', 'kana': 'かえます', 'romaji': 'kaemasu', 'group': 2},
#  {'kanji': '歩きます', 'kana': 'あるきます', 'romaji': 'arukimasu', 'group': 1},
#  {'kanji': '引っ越しします',
#   'kana': 'ひっこしします',
#   'romaji': 'hikkoshishimasu',
#   'group': 3},
#  {'kanji': 'くれます', 'kana': 'くれます', 'romaji': 'kuremasu', 'group': 2},
#  {'kanji': '直します', 'kana': 'なおします', 'romaji': 'naoshimasu', 'group': 1},
#  {'kanji': '連れて 行きます',
#   'kana': 'つれて いきます',
#   'romaji': 'tsurete ikimasu',
#   'group': 1},
#  {'kanji': '連れて 来ます',
#   'kana': 'つれて きます',
#   'romaji': 'tsurete kimasu',
#   'group': 3},
#  {'kanji': '紹介します', 'kana': 'しょうかいします', 'romaji': 'shōkaishimasu', 'group': 3},
#  {'kanji': '案内します', 'kana': 'あんないします', 'romaji': 'annaishimasu', 'group': 3},
#  {'kanji': '説明します',
#   'kana': 'せつめいします',
#   'romaji': 'setsumeishimasu',
#   'group': 3}]

# %%
manual_verbs_kanji = [
    '飛びます', '登ります', '走ります', 'もぐります', '飛び込みます', '逆立ちます', 'ほいます', 'けります', 
    '振ります', '持ち上げます', '投げます', 'たたきます', '引きます', '押します', '曲げます', '伸ばします', '転びます', 
    '振り向きますます'
]
manual_verbs_kana = [
    'とびます', 'のぼります', 'はしります', 'もぐります', 'とびこみます', 'さかだちます', 'ほいます', 'けります', 'ふります', 
    'もちあげます', 'なげます', 'たたきます', 'ひきます', 'おします', 'まげます', 'のばします', 'ころびます', 'ふりむきます'
]
manual_verbs_romaji = [
    'tobimasu', 'noborimasu', 'hashirimasu', 'mogurimasu', 'tobikomimasu', 'sakadachimasu', 'hoimasu', 'kerimasu',
    'furimasu', 'mochiagemasu', 'nagemasu', 'tatakimasu', 'hikimasu', 'oshimasu', 'magemasu', 'nobashimasu',
    'korobimasu', 'furimukimasu'
]

# %%
manual_verbs = [{'kanji': manual_verbs_kanji[i], 'kana': manual_verbs_kana[i], 'romaji': manual_verbs_romaji[i]} for i in range(len(manual_verbs_kana))]
for verb in manual_verbs:
    verb['group'] = group(verb)
manual_verbs
# Out:
# [{'kanji': '飛びます', 'kana': 'とびます', 'romaji': 'tobimasu', 'group': 1},
#  {'kanji': '登ります', 'kana': 'のぼります', 'romaji': 'noborimasu', 'group': 1},
#  {'kanji': '走ります', 'kana': 'はしります', 'romaji': 'hashirimasu', 'group': 1},
#  {'kanji': 'もぐります', 'kana': 'もぐります', 'romaji': 'mogurimasu', 'group': 1},
#  {'kanji': '飛び込みます', 'kana': 'とびこみます', 'romaji': 'tobikomimasu', 'group': 1},
#  {'kanji': '逆立ちます', 'kana': 'さかだちます', 'romaji': 'sakadachimasu', 'group': 1},
#  {'kanji': 'ほいます', 'kana': 'ほいます', 'romaji': 'hoimasu', 'group': 1},
#  {'kanji': 'けります', 'kana': 'けります', 'romaji': 'kerimasu', 'group': 1},
#  {'kanji': '振ります', 'kana': 'ふります', 'romaji': 'furimasu', 'group': 1},
#  {'kanji': '持ち上げます', 'kana': 'もちあげます', 'romaji': 'mochiagemasu', 'group': 2},
#  {'kanji': '投げます', 'kana': 'なげます', 'romaji': 'nagemasu', 'group': 2},
#  {'kanji': 'たたきます', 'kana': 'たたきます', 'romaji': 'tatakimasu', 'group': 1},
#  {'kanji': '引きます', 'kana': 'ひきます', 'romaji': 'hikimasu', 'group': 1},
#  {'kanji': '押します', 'kana': 'おします', 'romaji': 'oshimasu', 'group': 1},
#  {'kanji': '曲げます', 'kana': 'まげます', 'romaji': 'magemasu', 'group': 2},
#  {'kanji': '伸ばします', 'kana': 'のばします', 'romaji': 'nobashimasu', 'group': 1},
#  {'kanji': '転びます', 'kana': 'ころびます', 'romaji': 'korobimasu', 'group': 1},
#  {'kanji': '振り向きますます', 'kana': 'ふりむきます', 'romaji': 'furimukimasu', 'group': 1}]

# %%
verbs_complete = verbs + manual_verbs
verbs_complete
# Out:
# [{'kanji': '起きます', 'kana': 'おきます', 'romaji': 'okimasu', 'group': 2},
#  {'kanji': '寝ます', 'kana': 'ねます', 'romaji': 'nemasu', 'group': 2},
#  {'kanji': '働きます', 'kana': 'はたらきます', 'romaji': 'hatarakimasu', 'group': 1},
#  {'kanji': '休みます', 'kana': 'やすみます', 'romaji': 'yasumimasu', 'group': 1},
#  {'kanji': '勉強します', 'kana': 'べんきょうします', 'romaji': 'benkyōshimasu', 'group': 3},
#  {'kanji': '終わります', 'kana': 'おわります', 'romaji': 'owarimasu', 'group': 1},
#  {'kanji': '行きます', 'kana': 'いきます', 'romaji': 'ikimasu', 'group': 1},
#  {'kanji': '来ます', 'kana': 'きます', 'romaji': 'kimasu', 'group': 3},
#  {'kanji': '帰ります', 'kana': 'かえります', 'romaji': 'kaerimasu', 'group': 1},
#  {'kanji': '食べます', 'kana': 'たべます', 'romaji': 'tabemasu', 'group': 2},
#  {'kanji': '飲みます', 'kana': 'のみます', 'romaji': 'nomimasu', 'group': 1},
#  {'kanji': '見ます', 'kana': 'みます', 'romaji': 'mimasu', 'group': 2},
#  {'kanji': '聞きます', 'kana': 'ききます', 'romaji': 'kikimasu', 'group': 1},
#  {'kanji': '読みます', 'kana': 'よみます', 'romaji': 'yomimasu', 'group': 1},
#  {'kanji': '書きます', 'kana': 'かきます', 'romaji': 'kakimasu', 'group': 1},
#  {'kanji': '買います', 'kana': 'かいます', 'romaji': 'kaimasu', 'group': 1},
#  {'kanji': 'します', 'kana': 'します', 'romaji': 'shimasu', 'group': 2},
#  {'kanji': '切ります', 'kana': 'きります', 'romaji': 'kirimasu', 'group': 1},
#  {'kanji': '送ります', 'kana': 'おくります', 'romaji': 'okurimasu', 'group': 1},
#  {'kanji': 'あげます', 'kana': 'あげます', 'romaji': 'agemasu', 'group': 2},
#  {'kanji': 'もらいます', 'kana': 'もらいます', 'romaji': 'moraimasu', 'group': 1},
#  {'kanji': '貨します', 'kana': 'かします', 'romaji': 'kashimasu', 'group': 1},
#  {'kanji': '借ります', 'kana': 'かります', 'romaji': 'karimasu', 'group': 1},
#  {'kanji': '教えます', 'kana': 'おしえます', 'romaji': 'oshiemasu', 'group': 2},
#  {'kanji': '習います', 'kana': 'ならいます', 'romaji': 'naraimasu', 'group': 1},
#  {'kanji': 'わかります', 'kana': 'わかります', 'romaji': 'wakarimasu', 'group': 1},
#  {'kanji': 'あります', 'kana': 'あります', 'romaji': 'arimasu', 'group': 1},
#  {'kanji': 'あります', 'kana': 'あります', 'romaji': 'arimasu', 'group': 1},
#  {'kanji': 'います', 'kana': 'います', 'romaji': 'imasu', 'group': 2},
#  {'kanji': 'かかります', 'kana': 'かかります', 'romaji': 'kakarimasu', 'group': 1},
#  {'kanji': '遊びます', 'kana': 'あそびます', 'romaji': 'asobimasu', 'group': 1},
#  {'kanji': '泳ぎます', 'kana': 'およぎます', 'romaji': 'oyogimasu', 'group': 1},
#  {'kanji': '迎えます', 'kana': 'むかえます', 'romaji': 'mukaemasu', 'group': 2},
#  {'kanji': '疲れます', 'kana': 'つかれます', 'romaji': 'tsukaremasu', 'group': 2},
#  {'kanji': '結婚します', 'kana': 'けっこんします', 'romaji': 'kekkonshimasu', 'group': 3},
#  {'kanji': '買い物します',
#   'kana': 'かいものします',
#   'romaji': 'kaimonoshimasu',
#   'group': 3},
#  {'kanji': '食事します', 'kana': 'しょくじします', 'romaji': 'shokujishimasu', 'group': 3},
#  {'kanji': 'のどが かわきます',
#   'kana': 'のどが かわきます',
#   'romaji': 'nodoga kawakimasu',
#   'group': 1},
#  {'kanji': 'おなかが すきます',
#   'kana': 'おなかが すきます',
#   'romaji': 'onakaga sukimasu',
#   'group': 1},
#  {'kanji': 'つけます', 'kana': 'つけます', 'romaji': 'tsukemasu', 'group': 2},
#  {'kanji': '消します', 'kana': 'けします', 'romaji': 'keshimasu', 'group': 1},
#  {'kanji': '開けます', 'kana': 'あけます', 'romaji': 'akemasu', 'group': 2},
#  {'kanji': '閉めます', 'kana': 'しめます', 'romaji': 'shimemasu', 'group': 2},
#  {'kanji': '急ぎます', 'kana': 'いそぎます', 'romaji': 'isogimasu', 'group': 1},
#  {'kanji': '待ちます', 'kana': 'まちます', 'romaji': 'machimasu', 'group': 1},
#  {'kanji': '持ちます', 'kana': 'もちます', 'romaji': 'mochimasu', 'group': 1},
#  {'kanji': '取ります', 'kana': 'とります', 'romaji': 'torimasu', 'group': 1},
#  {'kanji': '手伝います', 'kana': 'てつだいます', 'romaji': 'tetsudaimasu', 'group': 1},
#  {'kanji': '呼びます', 'kana': 'よびます', 'romaji': 'yobimasu', 'group': 1},
#  {'kanji': '話します', 'kana': 'はなします', 'romaji': 'hanashimasu', 'group': 1},
#  {'kanji': '使います', 'kana': 'つかいます', 'romaji': 'tsukaimasu', 'group': 1},
#  {'kanji': '止めます', 'kana': 'とめます', 'romaji': 'tomemasu', 'group': 2},
#  {'kanji': '見せます', 'kana': 'みせます', 'romaji': 'misemasu', 'group': 2},
#  {'kanji': '座ります', 'kana': 'すわります', 'romaji': 'suwarimasu', 'group': 1},
#  {'kanji': '立ちます', 'kana': 'たちます', 'romaji': 'tachimasu', 'group': 1},
#  {'kanji': 'コピーします', 'kana': 'コピーします', 'romaji': 'kopiishimasu', 'group': 3},
#  {'kanji': '置きます', 'kana': 'おきます', 'romaji': 'okimasu', 'group': 1},
#  {'kanji': '作ります、造ります', 'kana': 'つくります', 'romaji': 'tsukurimasu', 'group': 1},
#  {'kanji': '売ります', 'kana': 'うります', 'romaji': 'urimasu', 'group': 1},
#  {'kanji': '知ります', 'kana': 'しります', 'romaji': 'shirimasu', 'group': 1},
#  {'kanji': '住みます', 'kana': 'すみます', 'romaji': 'sumimasu', 'group': 1},
#  {'kanji': '研究します', 'kana': 'けんきゅうします', 'romaji': 'kenkyūshimasu', 'group': 3},
#  {'kanji': '思い出します', 'kana': 'おもいだします', 'romaji': 'omoidashimasu', 'group': 3},
#  {'kanji': 'いらっしゃいます',
#   'kana': 'いらっしゃいます',
#   'romaji': 'irasshaimasu',
#   'group': 1},
#  {'kanji': '乗り換えます', 'kana': 'のりかえます', 'romaji': 'norikaemasu', 'group': 2},
#  {'kanji': '入れます', 'kana': 'いれます', 'romaji': 'iremasu', 'group': 2},
#  {'kanji': '出します', 'kana': 'だします', 'romaji': 'dashimasu', 'group': 1},
#  {'kanji': '押します', 'kana': 'おします', 'romaji': 'oshimasu', 'group': 1},
#  {'kanji': '飲みます', 'kana': 'のみます', 'romaji': 'nomimasu', 'group': 1},
#  {'kanji': '始めます', 'kana': 'はじめます', 'romaji': 'hajimemasu', 'group': 2},
#  {'kanji': '見学します', 'kana': 'けんがくします', 'romaji': 'kengakushimasu', 'group': 3},
#  {'kanji': '電話します', 'kana': 'でんわします', 'romaji': 'denwashimasu', 'group': 3},
#  {'kanji': '覚えます', 'kana': 'おぼえます', 'romaji': 'oboemasu', 'group': 2},
#  {'kanji': '忘れます', 'kana': 'わすれます', 'romaji': 'wasuremasu', 'group': 2},
#  {'kanji': 'なくします', 'kana': 'なくします', 'romaji': 'nakushimasu', 'group': 3},
#  {'kanji': '払います', 'kana': 'はらいます', 'romaji': 'haraimasu', 'group': 1},
#  {'kanji': '返します', 'kana': 'かえします', 'romaji': 'kaeshimasu', 'group': 1},
#  {'kanji': '出かけます', 'kana': 'でかけます', 'romaji': 'dekakemasu', 'group': 2},
#  {'kanji': '脱ぎます', 'kana': 'ぬぎます', 'romaji': 'nugimasu', 'group': 1},
#  {'kanji': '持って 行きます',
#   'kana': 'もって いきます',
#   'romaji': 'motte ikimasu',
#   'group': 1},
#  {'kanji': '持って 来ます', 'kana': 'もって きます', 'romaji': 'motte kimasu', 'group': 3},
#  {'kanji': '心配します', 'kana': 'しんぱいします', 'romaji': 'shinpaishimasu', 'group': 3},
#  {'kanji': '残業します', 'kana': 'ざんぎょうします', 'romaji': 'zangyōshimasu', 'group': 3},
#  {'kanji': '出張します',
#   'kana': 'しゅっちょうします',
#   'romaji': 'shutchōshimasu',
#   'group': 3},
#  {'kanji': 'できます', 'kana': 'できます', 'romaji': 'dekimasu', 'group': 2},
#  {'kanji': '洗います', 'kana': 'あらいます', 'romaji': 'araimasu', 'group': 1},
#  {'kanji': '弾きます', 'kana': 'ひきます', 'romaji': 'hikimasu', 'group': 1},
#  {'kanji': '歌います', 'kana': 'うたいます', 'romaji': 'utaimasu', 'group': 1},
#  {'kanji': '集めます', 'kana': 'あつめます', 'romaji': 'atsumemasu', 'group': 2},
#  {'kanji': '捨てます', 'kana': 'すてます', 'romaji': 'sutemasu', 'group': 2},
#  {'kanji': '換えます', 'kana': 'かえます', 'romaji': 'kaemasu', 'group': 2},
#  {'kanji': '運転します', 'kana': 'うんてんします', 'romaji': 'untenshimasu', 'group': 3},
#  {'kanji': '予約します', 'kana': 'よやくします', 'romaji': 'yoyakushimasu', 'group': 3},
#  {'kanji': '登ります、上ります', 'kana': 'のぼります', 'romaji': 'noborimasu', 'group': 1},
#  {'kanji': '掃除します', 'kana': 'そうじします', 'romaji': 'sōjishimasu', 'group': 3},
#  {'kanji': '洗濯します', 'kana': 'せんたくします', 'romaji': 'sentakushimasu', 'group': 3},
#  {'kanji': 'なります', 'kana': 'なります', 'romaji': 'narimasu', 'group': 1},
#  {'kanji': '調べます', 'kana': 'しらべます', 'romaji': 'shirabemasu', 'group': 2},
#  {'kanji': '修理します', 'kana': 'しゅうりします', 'romaji': 'shūrishimasu', 'group': 3},
#  {'kanji': '思います', 'kana': 'おもいます', 'romaji': 'omoimasu', 'group': 1},
#  {'kanji': '言います', 'kana': 'いいます', 'romaji': 'iimasu', 'group': 1},
#  {'kanji': '勝ちます', 'kana': 'かちます', 'romaji': 'kachimasu', 'group': 1},
#  {'kanji': '負けます', 'kana': 'まけます', 'romaji': 'makemasu', 'group': 2},
#  {'kanji': '動きます', 'kana': 'うごきます', 'romaji': 'ugokimasu', 'group': 1},
#  {'kanji': '留学します',
#   'kana': 'りゅうがくします',
#   'romaji': 'ryūgakushimasu',
#   'group': 3},
#  {'kanji': '着ます', 'kana': 'きます', 'romaji': 'kimasu', 'group': 2},
#  {'kanji': 'はきます', 'kana': 'はきます', 'romaji': 'hakimasu', 'group': 1},
#  {'kanji': 'かぶります', 'kana': 'かぶります', 'romaji': 'kaburimasu', 'group': 1},
#  {'kanji': '生まれます', 'kana': 'うまれます', 'romaji': 'umaremasu', 'group': 2},
#  {'kanji': '回します', 'kana': 'まわします', 'romaji': 'mawashimasu', 'group': 1},
#  {'kanji': '引きます', 'kana': 'ひきます', 'romaji': 'hikimasu', 'group': 1},
#  {'kanji': '変えます', 'kana': 'かえます', 'romaji': 'kaemasu', 'group': 2},
#  {'kanji': '歩きます', 'kana': 'あるきます', 'romaji': 'arukimasu', 'group': 1},
#  {'kanji': '引っ越しします',
#   'kana': 'ひっこしします',
#   'romaji': 'hikkoshishimasu',
#   'group': 3},
#  {'kanji': 'くれます', 'kana': 'くれます', 'romaji': 'kuremasu', 'group': 2},
#  {'kanji': '直します', 'kana': 'なおします', 'romaji': 'naoshimasu', 'group': 1},
#  {'kanji': '連れて 行きます',
#   'kana': 'つれて いきます',
#   'romaji': 'tsurete ikimasu',
#   'group': 1},
#  {'kanji': '連れて 来ます',
#   'kana': 'つれて きます',
#   'romaji': 'tsurete kimasu',
#   'group': 3},
#  {'kanji': '紹介します', 'kana': 'しょうかいします', 'romaji': 'shōkaishimasu', 'group': 3},
#  {'kanji': '案内します', 'kana': 'あんないします', 'romaji': 'annaishimasu', 'group': 3},
#  {'kanji': '説明します',
#   'kana': 'せつめいします',
#   'romaji': 'setsumeishimasu',
#   'group': 3},
#  {'kanji': '飛びます', 'kana': 'とびます', 'romaji': 'tobimasu', 'group': 1},
#  {'kanji': '登ります', 'kana': 'のぼります', 'romaji': 'noborimasu', 'group': 1},
#  {'kanji': '走ります', 'kana': 'はしります', 'romaji': 'hashirimasu', 'group': 1},
#  {'kanji': 'もぐります', 'kana': 'もぐります', 'romaji': 'mogurimasu', 'group': 1},
#  {'kanji': '飛び込みます', 'kana': 'とびこみます', 'romaji': 'tobikomimasu', 'group': 1},
#  {'kanji': '逆立ちます', 'kana': 'さかだちます', 'romaji': 'sakadachimasu', 'group': 1},
#  {'kanji': 'ほいます', 'kana': 'ほいます', 'romaji': 'hoimasu', 'group': 1},
#  {'kanji': 'けります', 'kana': 'けります', 'romaji': 'kerimasu', 'group': 1},
#  {'kanji': '振ります', 'kana': 'ふります', 'romaji': 'furimasu', 'group': 1},
#  {'kanji': '持ち上げます', 'kana': 'もちあげます', 'romaji': 'mochiagemasu', 'group': 2},
#  {'kanji': '投げます', 'kana': 'なげます', 'romaji': 'nagemasu', 'group': 2},
#  {'kanji': 'たたきます', 'kana': 'たたきます', 'romaji': 'tatakimasu', 'group': 1},
#  {'kanji': '引きます', 'kana': 'ひきます', 'romaji': 'hikimasu', 'group': 1},
#  {'kanji': '押します', 'kana': 'おします', 'romaji': 'oshimasu', 'group': 1},
#  {'kanji': '曲げます', 'kana': 'まげます', 'romaji': 'magemasu', 'group': 2},
#  {'kanji': '伸ばします', 'kana': 'のばします', 'romaji': 'nobashimasu', 'group': 1},
#  {'kanji': '転びます', 'kana': 'ころびます', 'romaji': 'korobimasu', 'group': 1},
#  {'kanji': '振り向きますます', 'kana': 'ふりむきます', 'romaji': 'furimukimasu', 'group': 1}]

# %%
df_verbs = pd.DataFrame(verbs_complete)
df_verbs
# Out:
#         kanji      kana         romaji  group
# 0        起きます      おきます        okimasu      2
# 1         寝ます       ねます         nemasu      2
# 2        働きます    はたらきます   hatarakimasu      1
# 3        休みます     やすみます     yasumimasu      1
# 4       勉強します  べんきょうします  benkyōshimasu      3
# ..        ...       ...            ...    ...
# 134      押します      おします       oshimasu      1
# 135      曲げます      まげます       magemasu      2
# 136     伸ばします     のばします    nobashimasu      1
# 137      転びます     ころびます     korobimasu      1
# 138  振り向きますます    ふりむきます   furimukimasu      1
#
# [139 rows x 4 columns]

# %%
df_verbs.to_excel('verbs.xlsx', index=False)

# %%
with open("verbs.json", "w") as outfile:
    json.dump(verbs, outfile)
